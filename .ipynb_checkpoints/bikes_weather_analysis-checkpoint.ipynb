# %% [markdown]
# https://ride.citibikenyc.com/system-data
# https://www.weather.gov/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the City Bike Trip data

# %%
df1 = pd.read_csv('../../DATA/202109-citibike-tripdata.csv', low_memory=False)

# %%
df1.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  22C33F42C6A0E28E  classic_bike  2021-09-01 10:26:45  2021-09-01 10:43:23
# 1  035F743147FCFCDE  classic_bike  2021-09-04 09:52:40  2021-09-04 10:09:19
# 2  9C43CF6A07DACBC6  classic_bike  2021-09-06 17:07:40  2021-09-06 17:34:44
# 3  253A1A5B20CC78EE  classic_bike  2021-09-28 16:53:43  2021-09-28 17:03:00
# 4  5E8F164D6798CEFA  classic_bike  2021-09-19 09:37:47  2021-09-19 09:53:42
#
#                 start_station_name  start_station_id         end_station_name  \
# 0      Central Park West & W 72 St           7141.07          E 51 St & 1 Ave
# 1             William St & Pine St           5065.12                      NaN
# 2             Fulton St & Broadway           5175.08         Jay St & Tech Pl
# 3  West Drive & Prospect Park West           3651.04  Ocean Pkwy & Church Ave
# 4            Lorimer St & Broadway           4965.01         Jay St & Tech Pl
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# 0        6532.06  40.775794 -73.976206  40.754557 -73.965930        member
# 1            NaN  40.707179 -74.008873  40.720000 -74.010000        member
# 2        4710.06  40.711066 -74.009447  40.695065 -73.987167        casual
# 3        3125.09  40.661063 -73.979453  40.644719 -73.974515        member
# 4        4710.06  40.704118 -73.948186  40.695065 -73.987167        member

# %%
df1.tail()
# Out:
#                   ride_id rideable_type           started_at  \
# 3280216  8A1C8DB4249BF100  classic_bike  2021-09-26 16:00:45
# 3280217  C290EE73DF58AD79  classic_bike  2021-09-07 08:22:06
# 3280218  E42F8B93C4168658  classic_bike  2021-09-30 20:50:23
# 3280219  7221F0C58026A827  classic_bike  2021-09-08 19:06:24
# 3280220  689F3FAE372C013C  classic_bike  2021-09-27 07:58:57
#
#                     ended_at          start_station_name  start_station_id  \
# 3280216  2021-09-26 16:20:51             8 Ave & W 31 St           6450.05
# 3280217  2021-09-07 08:38:40  S Portland Ave & Hanson Pl           4354.05
# 3280218  2021-09-30 20:59:13      West End Ave & W 60 St           7059.08
# 3280219  2021-09-08 19:10:57      West End Ave & W 60 St           7059.08
# 3280220  2021-09-27 08:02:31      West End Ave & W 60 St           7059.08
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 3280216       W 67 St & Broadway        7116.04  40.750585 -73.994685
# 3280217     S 3 St & Bedford Ave        5235.05  40.685396 -73.974315
# 3280218  Amsterdam Ave & W 66 St        7149.05  40.772370 -73.990050
# 3280219  Amsterdam Ave & W 66 St        7149.05  40.772370 -73.990050
# 3280220       W 67 St & Broadway        7116.04  40.772370 -73.990050
#
#            end_lat    end_lng member_casual
# 3280216  40.774925 -73.982666        casual
# 3280217  40.712605 -73.962644        casual
# 3280218  40.774667 -73.984706        casual
# 3280219  40.774667 -73.984706        member
# 3280220  40.774925 -73.982666        member

# %%
df1['started_at'] = pd.to_datetime(df1['started_at'])

# %%
df1['ended_at'] = pd.to_datetime(df1['ended_at'])

# %%
df1['started_at']
# Out:
# 0         2021-09-01 10:26:45
# 1         2021-09-04 09:52:40
# 2         2021-09-06 17:07:40
# 3         2021-09-28 16:53:43
# 4         2021-09-19 09:37:47
#                   ...
# 3280216   2021-09-26 16:00:45
# 3280217   2021-09-07 08:22:06
# 3280218   2021-09-30 20:50:23
# 3280219   2021-09-08 19:06:24
# 3280220   2021-09-27 07:58:57
# Name: started_at, Length: 3280221, dtype: datetime64[ns]

# %%
df1['started_at'].dt.month.unique()
# Out:
# array([9])

# %%
df1['started_at'].dt.day.min(), df1['started_at'].dt.day.max()
# Out:
# (1, 30)

# %%
df1['Date'] = pd.to_datetime(df1['started_at'].dt.date)

# %%
df1['Date']
# Out:
# 0         2021-09-01
# 1         2021-09-04
# 2         2021-09-06
# 3         2021-09-28
# 4         2021-09-19
#              ...
# 3280216   2021-09-26
# 3280217   2021-09-07
# 3280218   2021-09-30
# 3280219   2021-09-08
# 3280220   2021-09-27
# Name: Date, Length: 3280221, dtype: datetime64[ns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3280221 entries, 0 to 3280220
# Data columns (total 14 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    float64
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  Date                datetime64[ns]
# dtypes: datetime64[ns](3), float64(5), object(6)
# memory usage: 350.4+ MB

# %%
df1.isnull().sum()
# Out:
# ride_id                   0
# rideable_type             0
# started_at                0
# ended_at                  0
# start_station_name       18
# start_station_id         18
# end_station_name      15351
# end_station_id        15351
# start_lat                 0
# start_lng                 0
# end_lat                8784
# end_lng                8784
# member_casual             0
# Date                      0
# dtype: int64

# %% [markdown]
# ### Loading the Weather data

# %%
df2 = pd.read_csv('../../DATA/weather_data.csv', skiprows=4)

# %%
df2.columns = ['Date', 'Max_temperature', 'Min_temperature', 'Average_temp', 'Departure_temp',
              'HDD', 'CDD', 'Precipitation', 'New Snow', 'Snow Depth']

# %%
df2 = df2.iloc[:30]

# %%
df2
# Out:
#           Date Max_temperature  Min_temperature Average_temp Departure_temp  \
# 0   2021-09-01              78             63.0         70.5           -3.3
# 1   2021-09-02              77             61.0           69           -4.5
# 2   2021-09-03              74             59.0         66.5           -6.8
# 3   2021-09-04              79             61.0           70           -3.0
# 4   2021-09-05              74             67.0         70.5           -2.3
# 5   2021-09-06              81             69.0           75            2.5
# 6   2021-09-07              79             65.0           72           -0.2
# 7   2021-09-08              82             70.0           76            4.1
# 8   2021-09-09              76             68.0           72            0.4
# 9   2021-09-10              74             63.0         68.5           -2.8
# 10  2021-09-11              76             60.0           68           -3.0
# 11  2021-09-12              81             66.0         73.5            2.8
# 12  2021-09-13              83             67.0           75            4.6
# 13  2021-09-14              80             67.0         73.5            3.5
# 14  2021-09-15              85             71.0           78            8.3
# 15  2021-09-16              76             71.0         73.5            4.2
# 16  2021-09-17              75             69.0           72              3
# 17  2021-09-18              84             69.0         76.5            7.9
# 18  2021-09-19              76             64.0           70            1.8
# 19  2021-09-20              75             63.0           69            1.2
# 20  2021-09-21              76             63.0         69.5            2.1
# 21  2021-09-22              79             72.0         75.5            8.4
# 22  2021-09-23              79             64.0         71.5            4.8
# 23  2021-09-24              72             57.0         64.5           -1.8
# 24  2021-09-25              75             57.0           66            0.1
# 25  2021-09-26              71             61.0           66            0.5
# 26  2021-09-27              78             62.0           70            4.9
# 27  2021-09-28              71             61.0           66            1.3
# 28  2021-09-29              68             54.0           61           -3.3
# 29  2021-09-30              65             55.0           60           -3.9
#
#    HDD CDD Precipitation New Snow Snow Depth
# 0    0   6          7.13        0          0
# 1    0   4           0.1        0          0
# 2    0   2             0        0          0
# 3    0   5             0        0          0
# 4    0   6          0.02        0          0
# 5    0  10             T        0          0
# 6    0   7             0        0          0
# 7    0  11             0        0          0
# 8    0   7          0.26        0          0
# 9    0   4             0        0          0
# 10   0   3             0        0          0
# 11   0   9             0        0          0
# 12   0  10          0.12        0          0
# 13   0   9             0        0          0
# 14   0  13             T        0          0
# 15   0   9             T        0          0
# 16   0   7             T        0          0
# 17   0  12             0        0          0
# 18   0   5             0        0          0
# 19   0   4             0        0          0
# 20   0   5          0.09        0          0
# 21   0  11          0.01        0          0
# 22   0   7          1.37        0          0
# 23   0   0          0.66        0          0
# 24   0   1             0        0          0
# 25   0   1             0        0          0
# 26   0   5             0        0          0
# 27   0   1          0.27        0          0
# 28   4   0             T        0          0
# 29   5   0             0        0          M

# %% [markdown]
# #### Modify the features

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

# %% [markdown]
# Convert all temperature variables from Farrenheit to Celsius using the following formulae:
# \begin{equation}
# T_c = \frac{(T_f-32)5}{9}
# \end{equation}
# \begin{equation}
# \Delta T_c = \frac{\Delta T_f5}{9}
# \end{equation}

# %%
df2['Max_temperature'] = df2['Max_temperature'].apply(lambda x: np.round((float(x)-32)*5/9, 1))

# %%
df2['Min_temperature'] = df2['Min_temperature'].apply(lambda x: np.round((float(x)-32)*5/9, 1))

# %%
df2['Average_temp'] = df2['Average_temp'].apply(lambda x: np.round((float(x)-32)*5/9, 1))

# %%
df2['Departure_temp'] = df2['Departure_temp'].apply(lambda x: np.round(float(x)*5/9, 1))

# %%
df2['HDD'] = df2['HDD'].apply(lambda x: np.round(float(x)*5/9, 1))

# %%
df2['CDD'] = df2['CDD'].apply(lambda x: np.round(float(x)*5/9, 1))

# %% [markdown]
# In the Precipitation variable, the letter 'T' stands from 'Trace' - it means that the precipitation is so small that it is immeasurable so we can safely set it to 0.

# %%
df2['Precipitation'] = df2['Precipitation'].replace('T', 0).apply(float)

# %%
df2
# Out:
#          Date  Max_temperature  Min_temperature  Average_temp  Departure_temp  \
# 0  2021-09-01             25.6             17.2          21.4            -1.8
# 1  2021-09-02             25.0             16.1          20.6            -2.5
# 2  2021-09-03             23.3             15.0          19.2            -3.8
# 3  2021-09-04             26.1             16.1          21.1            -1.7
# 4  2021-09-05             23.3             19.4          21.4            -1.3
# 5  2021-09-06             27.2             20.6          23.9             1.4
# 6  2021-09-07             26.1             18.3          22.2            -0.1
# 7  2021-09-08             27.8             21.1          24.4             2.3
# 8  2021-09-09             24.4             20.0          22.2             0.2
# 9  2021-09-10             23.3             17.2          20.3            -1.6
# 10 2021-09-11             24.4             15.6          20.0            -1.7
# 11 2021-09-12             27.2             18.9          23.1             1.6
# 12 2021-09-13             28.3             19.4          23.9             2.6
# 13 2021-09-14             26.7             19.4          23.1             1.9
# 14 2021-09-15             29.4             21.7          25.6             4.6
# 15 2021-09-16             24.4             21.7          23.1             2.3
# 16 2021-09-17             23.9             20.6          22.2             1.7
# 17 2021-09-18             28.9             20.6          24.7             4.4
# 18 2021-09-19             24.4             17.8          21.1             1.0
# 19 2021-09-20             23.9             17.2          20.6             0.7
# 20 2021-09-21             24.4             17.2          20.8             1.2
# 21 2021-09-22             26.1             22.2          24.2             4.7
# 22 2021-09-23             26.1             17.8          21.9             2.7
# 23 2021-09-24             22.2             13.9          18.1            -1.0
# 24 2021-09-25             23.9             13.9          18.9             0.1
# 25 2021-09-26             21.7             16.1          18.9             0.3
# 26 2021-09-27             25.6             16.7          21.1             2.7
# 27 2021-09-28             21.7             16.1          18.9             0.7
# 28 2021-09-29             20.0             12.2          16.1            -1.8
# 29 2021-09-30             18.3             12.8          15.6            -2.2
#
#     HDD  CDD  Precipitation New Snow Snow Depth
# 0   0.0  3.3           7.13        0          0
# 1   0.0  2.2           0.10        0          0
# 2   0.0  1.1           0.00        0          0
# 3   0.0  2.8           0.00        0          0
# 4   0.0  3.3           0.02        0          0
# 5   0.0  5.6           0.00        0          0
# 6   0.0  3.9           0.00        0          0
# 7   0.0  6.1           0.00        0          0
# 8   0.0  3.9           0.26        0          0
# 9   0.0  2.2           0.00        0          0
# 10  0.0  1.7           0.00        0          0
# 11  0.0  5.0           0.00        0          0
# 12  0.0  5.6           0.12        0          0
# 13  0.0  5.0           0.00        0          0
# 14  0.0  7.2           0.00        0          0
# 15  0.0  5.0           0.00        0          0
# 16  0.0  3.9           0.00        0          0
# 17  0.0  6.7           0.00        0          0
# 18  0.0  2.8           0.00        0          0
# 19  0.0  2.2           0.00        0          0
# 20  0.0  2.8           0.09        0          0
# 21  0.0  6.1           0.01        0          0
# 22  0.0  3.9           1.37        0          0
# 23  0.0  0.0           0.66        0          0
# 24  0.0  0.6           0.00        0          0
# 25  0.0  0.6           0.00        0          0
# 26  0.0  2.8           0.00        0          0
# 27  0.0  0.6           0.27        0          0
# 28  2.2  0.0           0.00        0          0
# 29  2.8  0.0           0.00        0          M

# %% [markdown]
# There is no snow in September, so we drop those features.

# %%
df2 = df2.drop(['New Snow', 'Snow Depth'], axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             30 non-null     datetime64[ns]
#  1   Max_temperature  30 non-null     float64
#  2   Min_temperature  30 non-null     float64
#  3   Average_temp     30 non-null     float64
#  4   Departure_temp   30 non-null     float64
#  5   HDD              30 non-null     float64
#  6   CDD              30 non-null     float64
#  7   Precipitation    30 non-null     float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 2.0 KB

# %% [markdown]
# ### Merging the two datasets

# %%
df1['Date'].nunique(), df2['Date'].nunique()
# Out:
# (30, 30)

# %%
np.sort(df1['Date'].unique()) == df2['Date'].unique()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
df = df1.merge(df2, on='Date')

# %%
df.head().transpose()
# Out:
#                                               0                    1  \
# ride_id                        22C33F42C6A0E28E     EEF389AE0C7B62D7
# rideable_type                      classic_bike         classic_bike
# started_at                  2021-09-01 10:26:45  2021-09-01 15:53:39
# ended_at                    2021-09-01 10:43:23  2021-09-01 16:17:13
# start_station_name  Central Park West & W 72 St      2 Ave & E 31 St
# start_station_id                        7141.07              6197.02
# end_station_name                E 51 St & 1 Ave   S 4 St & Wythe Ave
# end_station_id                          6532.06              5204.05
# start_lat                             40.775794            40.742909
# start_lng                            -73.976206           -73.977061
# end_lat                               40.754557            40.712859
# end_lng                               -73.96593           -73.965903
# member_casual                            member               member
# Date                        2021-09-01 00:00:00  2021-09-01 00:00:00
# Max_temperature                            25.6                 25.6
# Min_temperature                            17.2                 17.2
# Average_temp                               21.4                 21.4
# Departure_temp                             -1.8                 -1.8
# HDD                                         0.0                  0.0
# CDD                                         3.3                  3.3
# Precipitation                              7.13                 7.13
#
#                                            2                       3  \
# ride_id                     8156B912E79C423A        BE198753368E271C
# rideable_type                   classic_bike            classic_bike
# started_at               2021-09-01 17:00:22     2021-09-01 10:42:37
# ended_at                 2021-09-01 17:40:07     2021-09-01 11:09:22
# start_station_name  Central Park W & W 97 St         8 Ave & W 38 St
# start_station_id                     7538.18                 6526.05
# end_station_name        Calyer St & Jewel St  Central Park S & 6 Ave
# end_station_id                       5743.02                 6876.04
# start_lat                          40.792495                40.75461
# start_lng                         -73.964171               -73.99177
# end_lat                             40.72984               40.765909
# end_lng                            -73.94839              -73.976342
# member_casual                         member                  casual
# Date                     2021-09-01 00:00:00     2021-09-01 00:00:00
# Max_temperature                         25.6                    25.6
# Min_temperature                         17.2                    17.2
# Average_temp                            21.4                    21.4
# Departure_temp                          -1.8                    -1.8
# HDD                                      0.0                     0.0
# CDD                                      3.3                     3.3
# Precipitation                           7.13                    7.13
#
#                                       4
# ride_id                F5EB435CEBD2AF48
# rideable_type              classic_bike
# started_at          2021-09-01 23:18:14
# ended_at            2021-09-02 08:23:49
# start_station_name      8 Ave & W 38 St
# start_station_id                6526.05
# end_station_name                    NaN
# end_station_id                      NaN
# start_lat                      40.75461
# start_lng                     -73.99177
# end_lat                             NaN
# end_lng                             NaN
# member_casual                    casual
# Date                2021-09-01 00:00:00
# Max_temperature                    25.6
# Min_temperature                    17.2
# Average_temp                       21.4
# Departure_temp                     -1.8
# HDD                                 0.0
# CDD                                 3.3
# Precipitation                      7.13

# %% [markdown]
# Next steps:
# - convert temperature from Farrenheit to Celsius
# - clarify the meaning of all features
# - clean the data (remove null values)
# - engineer new features
# - Group By date
# - investigate time evolution and dependance between features
# - eventually build a forecasting model
# - eventually plot start and end points of journeys on a map using plotly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3280221 entries, 0 to 3280220
# Data columns (total 21 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    float64
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  Date                datetime64[ns]
#  14  Max_temperature     float64
#  15  Min_temperature     float64
#  16  Average_temp        float64
#  17  Departure_temp      float64
#  18  HDD                 float64
#  19  CDD                 float64
#  20  Precipitation       float64
# dtypes: datetime64[ns](3), float64(12), object(6)
# memory usage: 550.6+ MB

# %% [markdown]
# ### Engineering new features

# %% [markdown]
# Time of each journey in minutes

# %%
df['ended_at'] - df['started_at']
# Out:
# 0         0 days 00:16:38
# 1         0 days 00:23:34
# 2         0 days 00:39:45
# 3         0 days 00:26:45
# 4         0 days 09:05:35
#                 ...
# 3280216   0 days 00:12:00
# 3280217   0 days 00:09:42
# 3280218   0 days 00:36:37
# 3280219   0 days 00:12:53
# 3280220   0 days 00:07:39
# Length: 3280221, dtype: timedelta64[ns]

# %%
df['minutes_of_journey'] = (df['ended_at'] - df['started_at']).dt.seconds//60

# %%
df['minutes_of_journey']
# Out:
# 0           16
# 1           23
# 2           39
# 3           26
# 4          545
#           ...
# 3280216     12
# 3280217      9
# 3280218     36
# 3280219     12
# 3280220      7
# Name: minutes_of_journey, Length: 3280221, dtype: int64

# %% [markdown]
# Does rider return to the same station that he started at (boolean)?

# %%
df['return_to_same_station'] = (df['start_station_name'] == df['end_station_name']).apply(int)

# %%
df['return_to_same_station'].sum()/len(df)
# Out:
# 0.049970108721333104

# %% [markdown]
# About 5% of the journeys return to the same station.

# %%
df['member_casual'].unique()
# Out:
# array(['member', 'casual'], dtype=object)

# %%
sns.countplot(data=df, x='member_casual');

# %%
df['day_of_week'] = df['Date'].dt.day_name()

# %%
df['day_of_week'].unique()
# Out:
# array(['Wednesday', 'Saturday', 'Monday', 'Tuesday', 'Sunday', 'Thursday',
#        'Friday'], dtype=object)

# %%
plt.figure(figsize=(10,6))

sns.countplot(data=df, x='day_of_week', palette='Set1',
             order=['Monday', 'Tuesday', 'Wednesday', 'Thursday',
                   'Friday', 'Saturday', 'Sunday']);

# %%
df['start_station_id'].nunique(), df['end_station_id'].nunique(), len(df)
# Out:
# (1488, 1524, 3280221)

# %%
df['rideable_type'].value_counts()
# Out:
# classic_bike     3247192
# docked_bike        33011
# electric_bike         18
# Name: rideable_type, dtype: int64

# %%
df['Member'] = df['member_casual'].replace({'member':1, 'casual':0})

# %%
df['Member'].value_counts()
# Out:
# 1    1889712
# 0    1390509
# Name: Member, dtype: int64

# %% [markdown]
# Hour during the day when journey started.

# %%
df['hour'] = df['started_at'].dt.hour

# %% [markdown]
# ### Group By Date

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'Date', 'Max_temperature', 'Min_temperature',
#        'Average_temp', 'Departure_temp', 'HDD', 'CDD', 'Precipitation',
#        'minutes_of_journey', 'return_to_same_station', 'day_of_week',
#        'Member'],
#       dtype='object')

# %%
d_agg = {'ride_id':'count',
         'minutes_of_journey':['mean', 'max'],
         'hour':'median',
         'day_of_week':'first',
         'return_to_same_station':'sum',
         'Member':'sum',
         'Max_temperature':'first',
         'Min_temperature':'first',
         'Average_temp':'first',
         'Precipitation':'first'}

# %%
df_daily = df.groupby('Date').agg(d_agg)

# %%
len(df_daily.columns)
# Out:
# 11

# %%
df_daily.columns = ['number_of_rides', 'mean_duration_of_ride', 'max_duration_of_ride',
                   'typical_hour_of_ride', 'day_of_week', 'num_return_same_station',
                   'num_members', 'max_temp', 'min_temp', 'average_temp', 'precipitation']

# %%
df_daily['num_casuals'] = df_daily['number_of_rides'] - df_daily['num_members']

# %%
df_daily
# Out:
#             number_of_rides  mean_duration_of_ride  max_duration_of_ride  \
# Date
# 2021-09-01            50782              13.484621                  1439
# 2021-09-02           126450              16.706176                  1439
# 2021-09-03           115060              16.631227                  1439
# 2021-09-04           109096              19.591736                  1439
# 2021-09-05            87491              18.606074                  1378
# 2021-09-06           106319              19.212587                  1439
# 2021-09-07           106915              15.294851                  1439
# 2021-09-08           113132              14.705724                  1439
# 2021-09-09            77648              13.893017                  1439
# 2021-09-10           126605              15.518092                  1439
# 2021-09-11           133564              19.152938                  1439
# 2021-09-12           117208              18.482424                  1439
# 2021-09-13           105983              15.488003                  1439
# 2021-09-14           118471              15.008711                  1439
# 2021-09-15           118359              14.870158                  1418
# 2021-09-16           109630              14.290979                  1436
# 2021-09-17           111908              14.954409                  1414
# 2021-09-18           124633              18.407059                  1417
# 2021-09-19           116461              18.714668                  1439
# 2021-09-20           109092              14.780461                  1432
# 2021-09-21           113237              14.966398                  1439
# 2021-09-22           113373              14.419042                  1439
# 2021-09-23            86729              13.949279                  1439
# 2021-09-24           115890              15.711545                  1439
# 2021-09-25           125178              18.905023                  1432
# 2021-09-26           113543              18.263151                  1439
# 2021-09-27           106803              14.873318                  1439
# 2021-09-28            96552              13.738586                  1398
# 2021-09-29           111532              17.394622                  1439
# 2021-09-30           112577              14.516535                  1405
#
#             typical_hour_of_ride day_of_week  num_return_same_station  \
# Date
# 2021-09-01                  13.0   Wednesday                     2650
# 2021-09-02                  15.0    Thursday                     6184
# 2021-09-03                  15.0      Friday                     5959
# 2021-09-04                  14.0    Saturday                     6517
# 2021-09-05                  15.0      Sunday                     5691
# 2021-09-06                  15.0      Monday                     7171
# 2021-09-07                  15.0     Tuesday                     5497
# 2021-09-08                  15.0   Wednesday                     5411
# 2021-09-09                  17.0    Thursday                     3591
# 2021-09-10                  15.0      Friday                     6134
# 2021-09-11                  14.0    Saturday                     7413
# 2021-09-12                  14.0      Sunday                     6818
# 2021-09-13                  15.0      Monday                     4932
# 2021-09-14                  15.0     Tuesday                     5296
# 2021-09-15                  15.0   Wednesday                     5279
# 2021-09-16                  15.0    Thursday                     5018
# 2021-09-17                  15.0      Friday                     4893
# 2021-09-18                  14.0    Saturday                     6708
# 2021-09-19                  14.0      Sunday                     6619
# 2021-09-20                  15.0      Monday                     5159
# 2021-09-21                  15.0     Tuesday                     4853
# 2021-09-22                  15.0   Wednesday                     4834
# 2021-09-23                  13.0    Thursday                     3766
# 2021-09-24                  15.0      Friday                     5418
# 2021-09-25                  14.0    Saturday                     6826
# 2021-09-26                  14.0      Sunday                     6865
# 2021-09-27                  15.0      Monday                     5002
# 2021-09-28                  15.0     Tuesday                     3965
# 2021-09-29                  15.0   Wednesday                     4739
# 2021-09-30                  15.0    Thursday                     4705
#
#             num_members  max_temp  min_temp  average_temp  precipitation
# Date
# 2021-09-01        31957      25.6      17.2          21.4           7.13
# 2021-09-02        67683      25.0      16.1          20.6           0.10
# 2021-09-03        62942      23.3      15.0          19.2           0.00
# 2021-09-04        50925      26.1      16.1          21.1           0.00
# 2021-09-05        41108      23.3      19.4          21.4           0.02
# 2021-09-06        52367      27.2      20.6          23.9           0.00
# 2021-09-07        64049      26.1      18.3          22.2           0.00
# 2021-09-08        69338      27.8      21.1          24.4           0.00
# 2021-09-09        48071      24.4      20.0          22.2           0.26
# 2021-09-10        73352      23.3      17.2          20.3           0.00
# 2021-09-11        65517      24.4      15.6          20.0           0.00
# 2021-09-12        58336      27.2      18.9          23.1           0.00
# 2021-09-13        66094      28.3      19.4          23.9           0.12
# 2021-09-14        74670      26.7      19.4          23.1           0.00
# 2021-09-15        74022      29.4      21.7          25.6           0.00
# 2021-09-16        67030      24.4      21.7          23.1           0.00
# 2021-09-17        67424      23.9      20.6          22.2           0.00
# 2021-09-18        63034      28.9      20.6          24.7           0.00
# 2021-09-19        58968      24.4      17.8          21.1           0.00
# 2021-09-20        68270      23.9      17.2          20.6           0.00
# 2021-09-21        71819      24.4      17.2          20.8           0.09
# 2021-09-22        72261      26.1      22.2          24.2           0.01
# 2021-09-23        56293      26.1      17.8          21.9           1.37
# 2021-09-24        69398      22.2      13.9          18.1           0.66
# 2021-09-25        62981      23.9      13.9          18.9           0.00
# 2021-09-26        57753      21.7      16.1          18.9           0.00
# 2021-09-27        67752      25.6      16.7          21.1           0.00
# 2021-09-28        63319      21.7      16.1          18.9           0.27
# 2021-09-29        71773      20.0      12.2          16.1           0.00
# 2021-09-30        71206      18.3      12.8          15.6           0.00

# %%
fig, ax = plt.subplots(figsize=(8,3), dpi=150)

df_daily['average_temp'].plot(ax=ax, label='Average temperature')
df_daily['min_temp'].plot(ax=ax, label='Minimal temperature')
df_daily['max_temp'].plot(ax=ax, label='Maximal temperature')

ax.set_ylabel('Temperature (Celsius)')

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,3), dpi=150)

df_daily['number_of_rides'].plot(ax=ax, label='Total number of rides')
df_daily['num_members'].plot(ax=ax, label='Number of members')
df_daily['num_casuals'].plot(ax=ax, label='Number of casuals')

ax.set_ylabel('Number of rides')

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,3), dpi=150)

df_daily['precipitation'].plot(ax=ax)

ax.set_ylabel('Precipitation (mm)')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,3), dpi=150)

df_daily['mean_duration_of_ride'].plot(ax=ax)

ax.set_ylabel('Mean duration of ride (minutes)')

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.barplot(data=df_daily, x='day_of_week', y='mean_duration_of_ride', estimator=np.mean,
           palette='Set1', order=['Monday', 'Tuesday', 'Wednesday', 'Thursday',
                   'Friday', 'Saturday', 'Sunday']);

# %%
plt.figure(figsize=(10,6))

sns.swarmplot(data=df_daily, x='day_of_week', y='num_casuals',
             palette='Set1', order=['Monday', 'Tuesday', 'Wednesday', 'Thursday',
                   'Friday', 'Saturday', 'Sunday'], size=10);

# %%
plt.figure(figsize=(10,6))

sns.swarmplot(data=df_daily, x='day_of_week', y='num_members',
             palette='Set1', order=['Monday', 'Tuesday', 'Wednesday', 'Thursday',
                   'Friday', 'Saturday', 'Sunday'], size=10);

# %%
plt.figure(figsize=(10,6))

sns.swarmplot(data=df_daily, x='day_of_week', y='typical_hour_of_ride',
           palette='Set1', order=['Monday', 'Tuesday', 'Wednesday', 'Thursday',
                   'Friday', 'Saturday', 'Sunday'], size=10);

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomp_duration = seasonal_decompose(df_daily['mean_duration_of_ride'], model='additive')

# %%
decomp_duration.plot();

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.3-cp37-cp37m-macosx_10_15_x86_64.whl (595 kB)
#      |████████████████████████████████| 595 kB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: pandas>=0.19 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: numpy>=1.19.3 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from pmdarima) (1.21.0)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from pmdarima) (0.24.2)
# Collecting urllib3
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from pmdarima) (1.7.1)
# Collecting Cython!=0.29.18,>=0.29
#   Using cached Cython-0.29.24-cp37-cp37m-macosx_10_9_x86_64.whl (1.9 MB)
# Requirement already satisfied: joblib>=0.11 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5 in /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Installing collected packages: urllib3, Cython, pmdarima
# Successfully installed Cython-0.29.24 pmdarima-1.8.3 urllib3-1.26.7
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Users/mgx82z/Desktop/Data_science/venv/bin/python -m pip install --upgrade pip' command.

# %%
from pmdarima import auto_arima

# %%
from statsmodels.tsa.arima_model import ARMA, ARMAResults, ARIMA, ARIMAResults

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
auto_arima(df_daily['num_casuals'], seasonal=True, m=7).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:                       y   No. Observations:                   30
# Model:             SARIMAX(0, 1, 0, 7)   Log Likelihood                -245.823
# Date:                 Mon, 11 Oct 2021   AIC                            493.645
# Time:                         13:25:06   BIC                            494.781
# Sample:                              0   HQIC                           493.931
#                                   - 30
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1.068e+08   2.31e+07      4.625      0.000    6.15e+07    1.52e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.87   Jarque-Bera (JB):                 1.81
# Prob(Q):                              0.09   Prob(JB):                         0.40
# Heteroskedasticity (H):               0.18   Skew:                            -0.17
# Prob(H) (two-sided):                  0.03   Kurtosis:                         4.33
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
train = df_daily.iloc[:28]
test = df_daily.iloc[28:]

# %%
model = SARIMAX(train['num_casuals'], exog=train['precipitation'], order=(1,0,0),
                seasonal_order=(0,1,0,7), enforce_invertibility=False)
results = model.fit()
results.summary()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.88602D+00    |proj g|=  3.11058D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      2      4      1     0     0   4.382D-06   7.886D+00
#   F =   7.8856868427508333
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# /Users/mgx82z/Desktop/Data_science/venv/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
#  This problem is unconstrained.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                       num_casuals   No. Observations:                   28
# Model:             SARIMAX(1, 0, 0)x(0, 1, 0, 7)   Log Likelihood                -220.799
# Date:                           Mon, 11 Oct 2021   AIC                            447.598
# Time:                                   13:48:59   BIC                            450.732
# Sample:                               09-01-2021   HQIC                           448.279
#                                     - 09-28-2021
# Covariance Type:                             opg
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# precipitation -3848.8995   6555.957     -0.587      0.557   -1.67e+04    9000.540
# ar.L1            -0.0392      0.329     -0.119      0.905      -0.684       0.605
# sigma2         8.326e+07      0.476   1.75e+08      0.000    8.33e+07    8.33e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                 7.84
# Prob(Q):                              0.75   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.11   Skew:                            -0.95
# Prob(H) (two-sided):                  0.01   Kurtosis:                         5.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.7e+24. Standard errors may be unstable.
# """

# %%
start=len(train)
end=len(train)+len(test)-1
exog_forecast = test[['precipitation']]  # requires two brackets to yield a shape of (35,1)
predictions = results.predict(start=start, end=end, exog=exog_forecast).rename('SARIMAX(1,0,0)(0,1,0,7) Predictions')

# %%
ax = df_daily['num_casuals'].plot(legend=True, figsize=(12,6), title='Number of casual riders')
predictions.plot(legend=True)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel='Day', ylabel='Number')
# Out:
# [Text(0.5, 0, 'Day'), Text(0, 0.5, 'Number')]

# %%
from statsmodels.tools.eval_measures import mse,rmse

# %%
error1x = mse(test['num_casuals'], predictions)
error2x = rmse(test['num_casuals'], predictions)

# Print new SARIMAX values
print(f'SARIMAX(1,0,0)(0,1,0,7) MSE Error: {error1x}')
print(f'SARIMAX(1,0,0)(0,1,0,7) RMSE Error: {error2x}')
# Out:
# SARIMAX(1,0,0)(0,1,0,7) MSE Error: 17514491.525258735
# SARIMAX(1,0,0)(0,1,0,7) RMSE Error: 4185.031842801048

# %%
test
# Out:
#             number_of_rides  mean_duration_of_ride  max_duration_of_ride  \
# Date
# 2021-09-29           111532              17.394622                  1439
# 2021-09-30           112577              14.516535                  1405
#
#             typical_hour_of_ride day_of_week  num_return_same_station  \
# Date
# 2021-09-29                  15.0   Wednesday                     4739
# 2021-09-30                  15.0    Thursday                     4705
#
#             num_members  max_temp  min_temp  average_temp  precipitation  \
# Date
# 2021-09-29        71773      20.0      12.2          16.1            0.0
# 2021-09-30        71206      18.3      12.8          15.6            0.0
#
#             num_casuals
# Date
# 2021-09-29        39759
# 2021-09-30        41371

# %%
error2x/test['num_casuals'].iloc[0]
# Out:
# 0.10525998749468166
